168,1689331531,1689474647,1689504945; ariaDefaultTheme=undefined; BAIDU_WISE_UID=wapp_1689514140540_870; RT="z=1&dm=baidu.com&si=e8d23d47-7b56-44c9-b916-104d22d410be&ss=lk5h18w4&sl=6&tt=kjl&bcn=https%3A%2F%2Ffclog.baidu.com%2Flog%2Fweirwood%3Ftype%3Dperf&nu=kpaxjfo&cl=7ws&ld=4q9b&ul=6a95&hd=6a9q"; BDRCVFR[GHvuHTY4eos]=Tc98Wv-QSrnmvPBmh68mvqV; H_PS_PSSID=; delPer=0; PSINO=7; BDORZ=FFFB88E999055A3F8A630C64834BD6D0; ab_sr=1.0.1_; BA_HECTOR=ala00h8k8121a0048g8k8h2m1ibagvk1o',
    'Host': 'fanyi.baidu.com',
    'Origin':'https://fanyi.baidu.com',
    'Referer':'https://fanyi.baidu.com/translate?aldtype=16047&query=Do+you+want+to+install+the+recommended+extensions+for+R%3F&keyfrom=baidu&smartresult=dict&lang=auto2zh',
    'Sec-Ch-Ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': 'Windows',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'
}
# post请求参数必需编码
data_encode=urllib.parse.urlencode(data).encode('utf-8')
request = urllib.request.Request(url,data_encode,header)
response = urllib.request.urlopen(request)
result = response.read().decode('utf-8')
# 将字符串变成json对象
import json
json.loads(result)
# Out:
# {'trans_result': {'data': [{'dst': '蜘蛛', 'src': 'spider'}],
#   'from': 'en',
#   'to': 'zh',
#   'status': 0,
#   'type': 2,
#   'phonetic': [{'src_str': '蜘', 'trg_str': 'zhī'},
#    {'src_str': '蛛', 'trg_str': 'zhū'}]},
#  'dict_result': {'edict': {'item': [{'tr_group': [{'tr': ['predatory arachnid with eight legs, two poison fangs, two feelers, and usually two silk-spinning organs at the back end of the body',
#         'they spin silk to make cocoons for eggs or traps for prey'],
#        'example': [],
#        'similar_word': []},
#       {'tr': ['a skillet made of cast iron'],
#        'example': [],
#        'similar_word': []},
#       {'tr': ['a computer program that prowls the internet looking for publicly accessible resources that can be added to a database',
#         'the database can then be searched with a search engine'],
#        'example': [],
#        'similar_word': ['wanderer']}],
#      'pos': 'noun'}],
#    'word': 'spider'},
#   'from': 'original',
# ...

# %%
url = 'https://fanyi.baidu.com/sug'
data = {
    'kw':'spider'
}
header={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}
# post请求参数必需编码
data_encode=urllib.parse.urlencode(data).encode('utf-8')
request = urllib.request.Request(url,data_encode,header)
response = urllib.request.urlopen(request)
result = response.read().decode('utf-8')
# 将字符串变成json对象
import json
json.loads(result)
# Out:
# {'errno': 0,
#  'data': [{'k': 'spider', 'v': 'n. 蜘蛛; 星形轮，十字叉; 带柄三脚平底锅; 三脚架'},
#   {'k': 'Spider', 'v': '[电影]蜘蛛'},
#   {'k': 'SPIDER', 'v': 'abbr. SEMATECH process induced damage effect revea'},
#   {'k': 'spiders', 'v': 'n. 蜘蛛( spider的名词复数 )'},
#   {'k': 'spidery', 'v': 'adj. 像蜘蛛腿一般细长的; 象蜘蛛网的，十分精致的'}]}

# %%
import urllib
import urllib.parse
