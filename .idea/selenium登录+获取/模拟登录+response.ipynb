# %%
from seleniumwire.utils import decode
import time
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
from io import BytesIO
import gzip
import time
browser = webdriver.Chrome()

browser.get('https://fanyi.baidu.com')

time.sleep(2)
textarea = browser.find_element(By.ID,'baidu_translate_input')
textarea.send_keys('how are you')
time.sleep(2)
body = decode(browser.requests[1].response.body, browser.requests[1].response.headers.get('Content-Encoding', 'identity'))
body = body.decode('utf-8')
body
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <meta charset="utf-8">\n        <!--IE内核浏览器，强制使用用户已安装的最高版本浏览器渲染，有Chrome框架的优先使用Chrome框架-->\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <title>百度翻译-200种语言互译、沟通全世界！</title>\n        <meta name="keywords" content="翻译,在线翻译,文档翻译,网页翻译,百度翻译,词典">\n        <meta name="description" content="百度翻译提供即时免费200+语言翻译服务，拥有网页、APP、API产品，支持文本翻译、文档翻译、图片翻译等特色功能，满足用户查词翻译、文献翻译、合同翻译等需求，随时随地沟通全世界">\n        <!--强制国内双核浏览器使用Webkit内核渲染页面-->\n        <!--360 6.X 以上可识别-->\n        <meta name="renderer" content="webkit">\n        <!--其他双核可识别-->\n        <meta name="force-rendering" content="webkit">\n        <script src="//passport.baidu.com/passApi/js/uni_login_wrapper.js?cdnversion=202308181643"></script>\n        <script>\n            var _hmt = _hmt || [];\n            (function() {\n              var hm = document.createElement("script");\n              hm.src = "//hm.baidu.com/hm.js?64ecd82404c51e03dc91cb9e8c025574";\n            
# ...

# %%
import time
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
from io import BytesIO
import gzip
import time
browser = webdriver.Chrome()

browser.get('https://fanyi.baidu.com')

time.sleep(2)
textarea = browser.find_element(By.ID,'baidu_translate_input')
textarea.send_keys('how are you')
time.sleep(2)
# 提取接口的请求信息
get_conver_header = {}
get_conver_url = ""
len(browser.requests)
for request in browser.requests:
    print(request.response)
    print(request.headers)
    if "https://fanyi.baidu.com" in request.url:
        get_conver_url = request.url
        for header_key in request.headers:
            get_conver_header[header_key] = request.headers[header_key]
        break
# get_conver_url
# get_conver_header
# browser.response_interceptor
rp_body = browser.requests[1].response.body
rp_body
# browser.requests[1]
buff = BytesIO(rp_body)
f = gzip.GzipFile(fileobj=buff)
htmls = f.read().decode('utf-8')
htmls
browser.quit()
# Out:
# 85
# 200
# content-length: 1
# origin: https://www.google.com
# content-type: application/x-www-form-urlencoded
# sec-fetch-site: none
# sec-fetch-mode: no-cors
# sec-fetch-dest: empty
# user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36
# accept-encoding: gzip, deflate, br
# accept-language: zh-CN,zh;q=0.9
#
#
# 200 OK
# Host: fanyi.baidu.com
# Connection: keep-alive
# sec-ch-ua: "Chromium";v="116", "Not)A;Brand";v="24", "Google Chrome";v="116"
# sec-ch-ua-mobile: ?0
# sec-ch-ua-platform: "Windows"
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
# Sec-Fetch-Site: none
# Sec-Fetch-Mode: navigate
# Sec-Fetch-User: ?1
# Sec-Fetch-Dest: document
# ...

# %%
import time
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
from io import BytesIO
import gzip
import time
browser = webdriver.Chrome()

browser.get('https://fanyi.baidu.com')

time.sleep(2)
textarea = browser.find_element(By.ID,'baidu_translate_input')
textarea.send_keys('how are you')
time.sleep(2)
# 提取接口的请求信息
get_conver_header = {}
get_conver_url = ""
len(browser.requests)
for request in browser.requests:
    print(request.url)
    if "https://fanyi.baidu.com" in request.url:
        get_conver_url = request.url
        for header_key in request.headers:
            get_conver_header[header_key] = request.headers[header_key]
        break
get_conver_url
get_conver_header
rp_body = browser.requests[1].response.body
rp_body
browser.requests[1]
buff = BytesIO(rp_body)
f = gzip.GzipFile(fileobj=buff)
htmls = f.read().decode('utf-8')
print(htmls)
browser.quit()
# Out:
# 94
# https://accounts.google.com/ListAccounts?gpsia=1&source=ChromiumBrowser&json=standard
# https://fanyi.baidu.com/
# 'https://fanyi.baidu.com/'
# {'Host': 'fanyi.baidu.com',
#  'Connection': 'keep-alive',
#  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Google Chrome";v="116"',
#  'sec-ch-ua-mobile': '?0',
#  'sec-ch-ua-platform': '"Windows"',
#  'Upgrade-Insecure-Requests': '1',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
#  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#  'Sec-Fetch-Site': 'none',
#  'Sec-Fetch-Mode': 'navigate',
#  'Sec-Fetch-User': '?1',
#  'Sec-Fetch-Dest': 'document',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Accept-Language': 'zh-CN,zh;q=0.9'}
# ...

# %%
browser.requests[1].response.body
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 browser.requests[1].response.body
#
# IndexError: list index out of range

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
from io import BytesIO
import gzip
browser = webdriver.Chrome()
browser.get('https://fanyi.baidu.com/sug')
browser.find_element(By.ID,'baidu_translate_input').send_keys('hello')
# browser.page_source
# 获取响应体的内容数据
rp_body = driver.requests[0].response.body
rp_body
buff = BytesIO(rp_body)
f = gzip.GzipFile(fileobj=buff)
htmls = f.read().decode('utf-8')
print(htmls)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 7
#       5 browser = webdriver.Chrome()
#       6 browser.get('https://fanyi.baidu.com/sug')
# ----> 7 browser.find_element(By.ID,'baidu_translate_input').send_keys('hello')
#       8 # browser.page_source
#       9 # 获取响应体的内容数据
#      10 rp_body = driver.requests[0].response.body
#
# File C:\ProgramData\Anaconda3\envs\selenium-wire\lib\site-packages\selenium\webdriver\remote\webdriver.py:739, in WebDriver.find_element(self, by, value)
#     736     by = By.CSS_SELECTOR
#     737     value = f'[name="{value}"]'
# --> 739 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ProgramData\Anaconda3\envs\selenium-wire\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
# ...

# %%
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()
browser.get('https://fanyi.baidu.com/sug')
browser.page_source
# 获取响应体的内容数据
rp_body = driver.requests[0].response.body
# Out:
# '<html><head><script type="text/javascript" charset="utf-8" src="https://pss.bdstatic.com/static/superman/js/components/advert-064271ed9b.js"></script><script type="text/javascript" charset="utf-8" src="https://pss.bdstatic.com/static/superman/js/components/qrcode-0e4b67354f.js"></script><script type="text/javascript" charset="utf-8" src="https://pss.bdstatic.com/static/superman/js/super_load-86e18c5005.js"></script><script type="text/javascript" charset="utf-8" src="https://pss.bdstatic.com/static/superman/js/components/tips-e2ceadd14d.js"></script><meta http-equiv="Content-Type" content="text/html;charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta content="always" name="referrer"><meta name="theme-color" content="#ffffff"><meta name="description" content="全球领先的中文搜索引擎、致力于让网民更便捷地获取信息，找到所求。百度超过千亿的中文网页数据库，可以瞬间找到相关的搜索结果。"><link rel="shortcut icon" href="https://www.baidu.com/favicon.ico" type="image/x-icon"><link rel="search" type="application/opensearchd
# ...

# %%
# 提取接口的请求信息
get_conver_header = {}
get_conver_url = ""
for request in browser.requests:
    if "http://www.baidu.com" in request.url:
        get_conver_url = request.url
        for header_key in request.headers:
            get_conver_header[header_key] = request.headers[header_key]
        break
get_conver_url
get_conver_header
from io import BytesIO
import gzip

# 清空之前获取的请求信息
del driver.requests

# 获取响应体的内容数据
rp_body = driver.requests[0].response.body

# 获取到的编码为byte数据，需要解码为utf-8，直接解码会报错
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte
# print输出的字节码是以"b’\x1f\x8b\x08"开头的，说明它是gzip压缩过的数据，所以我们要对字节码进行一个解码操作
buff = BytesIO(rp_body)
f = gzip.GzipFile(fileobj=buff)
htmls = f.read().decode('utf-8')
print(htmls)
# Out:
# 'http://www.baidu.com/'
# {'Host': 'www.baidu.com',
#  'Proxy-Connection': 'keep-alive',
#  'Upgrade-Insecure-Requests': '1',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
#  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#  'Accept-Encoding': 'gzip, deflate',
#  'Accept-Language': 'zh-CN,zh;q=0.9'}

# %%
from selenium import webdriver
url = 'https://fanyi.baidu.com/sug'
browser = webdriver.Chrome(r'C:\Users\fzh00\IdeaProjects\python_idea\.idea\chromedriver.exe')
browser.get(url)
input = browser.find_element_by_tag_name('textarea')
input
browser.page_source
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 5
#       3 browser = webdriver.Chrome(r'C:\Users\fzh00\IdeaProjects\python_idea\.idea\chromedriver.exe')
#       4 browser.get(url)
# ----> 5 input = browser.find_element_by_tag_name('textarea')
#       6 input
#       7 browser.page_source
#
# File C:\ProgramData\Anaconda3\envs\cda_python\lib\site-packages\selenium\webdriver\remote\webdriver.py:530, in WebDriver.find_element_by_tag_name(self, name)
#     514 def find_element_by_tag_name(self, name):
#     515     """
#     516     Finds an element by tag name.
#     517
#    (...)
#     528         element = driver.find_element_by_tag_name('h1')
#     529     """
# --> 530     return self.find_element(by=By.TAG_NAME, value=name)
#
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
