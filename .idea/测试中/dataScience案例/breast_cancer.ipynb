# %%
import pandas as pd

pd.DataFrame(y).plot('pie')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 pd.DataFrame(y).plot('pie')
#
# File C:\ProgramData\Anaconda3\envs\cda_python\lib\site-packages\pandas\plotting\_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
#     963 if is_integer(x) and not data.columns.holds_integer():
#     964     x = data_cols[x]
# --> 965 elif not isinstance(data[x], ABCSeries):
#     966     raise ValueError("x must be a label or position")
#     967 data = data.set_index(x)
#
# File C:\ProgramData\Anaconda3\envs\cda_python\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# ...

# %%
x[:3]
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#         3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#         8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#         3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#         1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, 1.326e+03, 8.474e-02, 7.864e-02,
#         8.690e-02, 7.017e-02, 1.812e-01, 5.667e-02, 5.435e-01, 7.339e-01,
#         3.398e+00, 7.408e+01, 5.225e-03, 1.308e-02, 1.860e-02, 1.340e-02,
#         1.389e-02, 3.532e-03, 2.499e+01, 2.341e+01, 1.588e+02, 1.956e+03,
#         1.238e-01, 1.866e-01, 2.416e-01, 1.860e-01, 2.750e-01, 8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, 1.203e+03, 1.096e-01, 1.599e-01,
#         1.974e-01, 1.279e-01, 2.069e-01, 5.999e-02, 7.456e-01, 7.869e-01,
#         4.585e+00, 9.403e+01, 6.150e-03, 4.006e-02, 3.832e-02, 2.058e-02,
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
x = cancer['data']
y = cancer['target']

# %%
data = pd.DataFrame(x).join(pd.DataFrame(y).rename(columns={0:'lab'}))

# %%
data.head(2)
# Out:
#        0      1      2       3        4        5       6        7       8  \
# 0  17.99  10.38  122.8  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.9  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
#
#          9  ...     21     22      23      24      25      26      27      28  \
# 0  0.07871  ...  17.33  184.6  2019.0  0.1622  0.6656  0.7119  0.2654  0.4601
# 1  0.05667  ...  23.41  158.8  1956.0  0.1238  0.1866  0.2416  0.1860  0.2750
#
#         29  lab
# 0  0.11890    0
# 1  0.08902    0
#
# [2 rows x 31 columns]

# %%
data.lab.value_counts()
# Out:
# 1    357
# 0    212
# Name: lab, dtype: int64

# %%
data.describe()
# Out:
#                 0           1           2            3           4  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                 5           6           7           8           9  ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.104341    0.088799    0.048919    0.181162    0.062798  ...
# std      0.052813    0.079720    0.038803    0.027414    0.007060  ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960  ...
# ...

# %%
data.T
# Out:
#              0            1            2           3            4    \
# 0      17.990000    20.570000    19.690000   11.420000    20.290000
# 1      10.380000    17.770000    21.250000   20.380000    14.340000
# 2     122.800000   132.900000   130.000000   77.580000   135.100000
# 3    1001.000000  1326.000000  1203.000000  386.100000  1297.000000
# 4       0.118400     0.084740     0.109600    0.142500     0.100300
# 5       0.277600     0.078640     0.159900    0.283900     0.132800
# 6       0.300100     0.086900     0.197400    0.241400     0.198000
# 7       0.147100     0.070170     0.127900    0.105200     0.104300
# 8       0.241900     0.181200     0.206900    0.259700     0.180900
# 9       0.078710     0.056670     0.059990    0.097440     0.058830
# 10      1.095000     0.543500     0.745600    0.495600     0.757200
# 11      0.905300     0.733900     0.786900    1.156000     0.781300
# 12      8.589000     3.398000     4.585000    3.445000     5.438000
# ...

# %%
from scipy import stats
stats.ttest_1samp(data.iloc[:,0],popmean=14)
# Out:
# Ttest_1sampResult(statistic=0.8616173566232037, pvalue=0.3892617071079777)

# %%
stats.jarque_bera(df['open'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 stats.jarque_bera(df['open'])
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
data.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
plt.boxplot(data);

# %%
import seaborn as sns
sns.boxplot(data)
# Out:
# <AxesSubplot: >

# %%
# %conda
# Out:
# usage: conda-script.py [-h] [-V] command ...
# Note: you may need to restart the kernel to use updated packages.
#
#
# conda is a tool for managing and deploying applications, environments and packages.
#
# Options:
#
# positional arguments:
#   command
#     clean        Remove unused packages and caches.
#     compare      Compare packages between conda environments.
#     config       Modify configuration values in .condarc. This is modeled
#                  after the git config command. Writes to the user .condarc
#                  file (C:\Users\fzh00\.condarc) by default.
#     create       Create a new conda environment from a list of specified
#                  packages.
#     help         Displays a list of available conda commands and their help
#                  strings.
#     info         Display information about current conda install.
#     init         Initialize conda for shell interaction. [Experimental]
# ...

# %%
data2 = data.set_index(0)

# %%
data2.reset_index(drop=True).head()
# Out:
#        1       2       3        4        5       6        7       8        9  \
# 0  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419  0.07871
# 1  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812  0.05667
# 2  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069  0.05999
# 3  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597  0.09744
# 4  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809  0.05883
#
#        10  ...     21      22      23      24      25      26      27      28  \
# 0  1.0950  ...  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654  0.4601
# 1  0.5435  ...  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860  0.2750
# 2  0.7456  ...  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430  0.3613
# 3  0.4956  ...  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575  0.6638
# 4  0.7572  ...  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625  0.2364
#
#         29  lab
# 0  0.11890    0
# ...

# %%
data2.index.has_duplicates
# Out:
# True

# %%
import pandas as pd
import numpy as np

# %%
import tushare as ts
df = ts.get_hist_data('000875')
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import tushare as ts
#       2 df = ts.get_hist_data('000875')
#       3 df.head(2)
#
# ModuleNotFoundError: No module named 'tushare'
