# %%
dir()
# Out:
# ['DataFrame',
#  'In',
#  'MultiIndex',
#  'Out',
#  '_',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_pydevd_bundle',
#  'exit',
#  'get_ipython',
#  'open',
#  'os',
#  'pydev_jupyter_vars',
#  'quit',
#  'remove_imported_pydev_package',
#  'sys',
#  'x']

# %%
import pickle
ofname = open('ch05/dataset_small.pkl','rb')
(x,y) = pickle.load(ofname, encoding="latin1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pickle
#       2 ofname = open('ch05/dataset_small.pkl','rb')
# ----> 3 (x,y) = pickle.load(ofname, encoding="latin1")
#
# ModuleNotFoundError: No module named 'numpy.core.multiarray\r'

# %%
print()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(12, 4))
plt.ylabel('Number of accidents')
plt.xlabel('Day')
plt.plot(range(0, 365), np.array(accidents), 'b-+', lw=0.7, alpha=0.7)
plt.plot(range(0, 365), [accidents.mean()]*365, 'r-', lw=0.7, alpha=0.9)
plt.show();

# %%
data['Date'] = pd.to_datetime(data['Date'])
accidents = data.groupby(['Date']).size()
accidents
accidents.mean()
# Out:
# Date
# 2013-01-01    16
# 2013-01-02    18
# 2013-01-03    17
# 2013-01-04    29
# 2013-01-05    17
#               ..
# 2013-12-27    21
# 2013-12-28    12
# 2013-12-29    13
# 2013-12-30    26
# 2013-12-31    19
# Length: 365, dtype: int64
# 25.90958904109589

# %%
#Create a new column which is the date
data = acc
data['Date'] = '2013-'+data['Mes de any'].apply(lambda x : str(x)) + '-' +  data['Dia de mes'].apply(lambda x : str(x))
data['Date'].head()
# Out:
# 0    2013-10-16
# 1    2013-10-29
# 2     2013-7-23
# 3     2013-2-26
# 4    2013-11-18
# Name: Date, dtype: object

# %%
import numpy as np
import pandas as pd
acc = pd.read_csv('ch04/ACCIDENTS_GU_BCN_2013.csv',encoding='latin-1')
acc.head()
# Out:
#   Número d'expedient  Codi districte Nom districte   NK barri  \
# 0        2013S007360              -1    Desconegut   -1--1--1
# 1        2013S007723              10    Sant Martí  101-10-64
# 2        2013S005373              10    Sant Martí  101-10-64
# 3        2013S001486              10    Sant Martí  101-10-64
# 4        2013S008254              10    Sant Martí  101-10-64
#
#                     Nom barri  Codi carrer     Nom carrer Num postal caption  \
# 0                  Desconegut           -1     Desconegut         Desconegut
# 1  el Camp de l'Arpa del Clot       152600       Guinardó          0028 0032
# 2  el Camp de l'Arpa del Clot       134801         Freser          0053 0053
# 3  el Camp de l'Arpa del Clot       161407      Indústria          0224 0224
# 4  el Camp de l'Arpa del Clot       161101  Independència          0357 0357
#
#   Descripció dia setmana  Dia de setmana  ... Hora de dia  Descripció torn  \
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings("ignore")

import os
os.chdir(r'C:\Users\fzh00\PycharmProjects\introduction-datascience-python-book\files')
