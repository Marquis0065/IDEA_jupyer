# %%
# Out:
# -0.451721394541571

# %%
predictions = tree_prediction
valid=df[x.shape[0]:]
valid['预测']=predictions
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Days')
plt.ylabel('Close Price in USD')
plt.plot(df['收盘'])
plt.plot(valid[['收盘', '预测']])
plt.legend(['Original','Valid', 'Predicted'])
plt.show()
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_18300\256756588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['预测']=predictions
# Text(0.5, 1.0, 'Model')
# Text(0.5, 0, 'Days')
# Text(0, 0.5, 'Close Price in USD')
# ...

# %%
from sklearn import tree
tree = tree.DecisionTreeRegressor().fit(x_train, y_train)
tree_prediction=tree.predict(xf)
print(tree_prediction)
# Out:
# [7.64 7.79 7.84 7.62 7.71 7.22 6.02 7.74 7.7  7.7  7.61 7.58 6.05 7.22
#  7.26 7.15 7.11 6.58 7.57 7.14 7.2  7.64 7.64 7.62 7.59 7.54 7.67 7.98
#  7.7  6.34 7.61 7.73 7.9  7.9  8.06 8.   8.05 7.93 7.97 7.89 7.91 7.74
#  7.98 7.88 7.78 7.91 7.74 7.73 7.72 7.61]

# %%
import matplotlib.pyplot as plt
predictions = lr_prediction
valid=df[x.shape[0]:]
valid['预测']=predictions
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Days')
plt.ylabel('Close Price in CNY')
plt.plot(df['收盘'])
plt.plot(valid[['收盘', '预测']])
plt.legend(['Original','Valid', 'pre'])
plt.show();
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_18300\1686056825.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['预测']=predictions

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(x_train, y_train)
lr_prediction=lr.predict(xf)
print(lr_prediction)
# Out:
# [6.90522012 6.86147228 6.78061189 6.93487084 7.03080109 6.99063662
#  7.15544645 7.17917052 7.23023674 7.22965037 7.24006261 7.24671594
#  7.00761353 7.03908406 7.01669964 7.03908544 7.04780373 7.00269252
#  6.96295781 7.00124576 6.96614197 6.9592475  7.03452895 7.1887568
#  7.24948727 7.26524969 7.18892611 7.26848064 7.24257567 7.32139986
#  7.3304297  7.28441735 7.41397713 7.43561392 7.46477171 7.36241732
#  7.41865648 7.33621863 7.26749091 7.30723501 7.31475922 7.35919945
#  7.40811593 7.43890972 7.30300759 7.26181493 7.31816733 7.29442522
#  7.39890391 7.45457111]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.25)

# %%
xf  = df.drop(['预测'], 1)[:-fd]
xf = xf.tail(fd)
xf=np.array(xf)
xf
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_18300\1336666576.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   xf  = df.drop(['预测'], 1)[:-fd]
# array([[ 6.75000000e+00,  2.07407407e+00, -1.47928994e-01,
#          3.87353320e+07],
#        [ 6.66000000e+00,  2.70270270e+00, -1.33333333e+00,
#          3.40227480e+07],
#        [ 6.46000000e+00,  3.56037152e+00, -2.71084337e+00,
#          5.32973000e+07],
#        [ 6.85000000e+00,  4.37956204e-01,  6.20155039e+00,
#          6.88309120e+07],
#        [ 7.03000000e+00,  4.26742532e+00,  4.30267062e+00,
#          1.41637856e+08],
#        [ 6.94000000e+00,  3.02593660e+00,  5.79710145e-01,
#          6.36694840e+07],
#        [ 7.29000000e+00,  2.46913580e+00,  5.04322767e+00,
#          1.14225440e+08],
#        [ 7.31000000e+00,  5.47195622e-01,  2.38095238e+00,
#          5.33245800e+07],
# ...

# %%
y = np.array(df['预测'])[:-fd]
y
# Out:
# array([6.19, 6.16, 6.09, 5.91, 5.82, 5.72, 5.8 , 5.82, 5.84, 5.82, 5.72,
#        5.84, 5.7 , 5.78, 6.07, 6.24, 6.24, 6.24, 6.48, 6.43, 6.42, 6.33,
#        6.36, 6.3 , 6.19, 6.18, 6.26, 6.16, 6.28, 6.56, 6.42, 6.43, 6.34,
#        6.38, 6.44, 6.88, 6.73, 6.65, 6.7 , 6.87, 6.74, 6.7 , 6.62, 6.63,
#        6.73, 6.64, 6.64, 6.6 , 6.53, 6.44, 6.2 , 6.12, 6.2 , 6.19, 6.27,
#        6.16, 6.47, 6.44, 6.5 , 6.5 , 6.31, 6.24, 6.16, 6.28, 6.23, 6.15,
#        6.2 , 6.21, 6.23, 6.25, 6.53, 6.51, 6.72, 6.8 , 6.81, 6.96, 7.2 ,
#        6.97, 7.  , 7.12, 7.11, 7.13, 7.05, 6.95, 6.96, 7.2 , 7.1 , 7.18,
#        7.26, 7.15, 7.23, 7.18, 7.22, 7.33, 7.36, 7.5 , 7.56, 7.8 , 7.62,
#        7.41, 7.34, 7.37, 7.21, 7.35, 7.33, 7.21, 7.05, 7.01, 6.94, 6.93,
#        7.07, 7.05, 7.29, 7.25, 6.54, 6.37, 6.32, 6.48, 6.71, 6.21, 5.91,
#        6.5 , 6.66, 6.72, 6.68, 6.62, 6.57, 6.51, 6.28, 6.23, 6.18, 6.39,
#        6.19, 6.49, 6.58, 6.6 , 6.75, 6.46, 6.98, 6.77, 6.87, 6.85, 6.93,
# ...

# %%
x=np.array(df.drop(['预测'],1))[:-fd]
from sklearn import preprocessing
# x = preprocessing.scale(x)
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_18300\3804089545.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x=np.array(df.drop(['预测'],1))[:-fd]

# %%
df.iloc[-52:-48,:]
# Out:
#        收盘       变化率        变化       成交量    预测
# 368  7.78  0.642674  2.910053  58446416  7.72
# 369  7.88  1.015228  1.025641  51231844  7.61
# 370  7.64  3.141361 -2.798982  66282296   NaN
# 371  7.79  0.641849  1.697128  53854736   NaN

# %%
fd = 50
df['预测'] = df['收盘'].shift(-fd)
df.head()
df.tail()
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_18300\2981277756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['预测'] = df['收盘'].shift(-fd)
#      收盘       变化率        变化       成交量    预测
# 0  6.01  0.665557 -0.661157  21898182  6.19
# 1  5.95  1.512605 -0.833333  28445196  6.16
# 2  5.88  1.190476 -1.010101  26998688  6.09
# 3  5.91  0.676819  0.681431  39321672  5.91
# 4  5.89  0.339559  0.000000  21759570  5.82
#        收盘       变化率        变化       成交量  预测
# 415  7.91  2.275601  1.540436  65759772 NaN
# 416  7.74  2.713178 -2.272727  35169180 NaN
# 417  7.73  1.293661 -0.129199  42502524 NaN
# 418  7.72  0.777202 -0.258398  30128864 NaN
# 419  7.61  1.445466 -1.424870  28445306 NaN

# %%
df.head()
# Out:
#      收盘       变化率        变化       成交量    预测
# 0  6.01  0.665557 -0.661157  21898182  6.19
# 1  5.95  1.512605 -0.833333  28445196  6.16
# 2  5.88  1.190476 -1.010101  26998688  6.09
# 3  5.91  0.676819  0.681431  39321672  5.91
# 4  5.89  0.339559  0.000000  21759570  5.82

# %%
import time

import matplotlib.pyplot as plt
from matplotlib import style
import datetime
style.use('ggplot')
one_day = 86400
# df['forecast']= np.nan
last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
next_unix = last_date + one_day
# 遍历
for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unit += one_day
    df.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)]+[i]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 8
#       6 # df['forecast']= np.nan
#       7 last_date = df.iloc[-1].name
# ----> 8 last_unix = last_date.timestamp()
#       9 next_unix = last_date + one_day
#      10 # 遍历
#
# AttributeError: 'int' object has no attribute 'timestamp'

# %%
24*60*60
# Out:
# 86400

# %%
data.head(2)
# Out:
#             时间    开盘    最高    最低    收盘       成交量       变化率        变化    收盘  \
# 0   2021/07/01  6.05  6.05  5.99  6.01  21898182  0.665557 -0.661157  6.01
# 1   2021/07/02  6.00  6.04  5.94  5.95  28445196  1.512605 -0.833333  5.95
#
#         变化率        变化       成交量  label  forecast
# 0  0.665557 -0.661157  21898182   5.77       NaN
# 1  1.512605 -0.833333  28445196   5.89       NaN

# %%
# 预测
forecast_set  = clf.predict(X_late)
print(forecast_set,acc)
# Out:
# [7.76714889 7.66788243 7.66213142 7.65281573 7.5638777 ] 0.758182242633958

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train,Y_train)
# 评估准确性
acc = clf.score(X_test,Y_test)
# Out:
# LinearRegression()

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.2)

# %%
y_late = y[-forecast_out:]
y = y[:-forecast_out]

# %%
# 分割测试集训练集
from sklearn.model_selection import train_test_split
from sklearn import svm

# %%
y = np.array(df['label'])

# %%
X_late = X[-forecast_out:]
X = X[:-forecast_out]

# %%
X = np.array(df.drop('label',1))
from  sklearn import preprocessing
X = preprocessing.scale(X)
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_11092\3208019952.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(df.drop('label',1))

# %%
df['label'] = df[forecast_col].shift(-forecast_out)
df.fillna(-99999,inplace=True)
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_11092\980219589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df[forecast_col].shift(-forecast_out)
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_11092\980219589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(-99999,inplace=True)

# %%
# 定义预测变量
forecast_col = '收盘'
# 定义预测天数
import math
forecast_out = int(math.ceil(0.01*len(df)))

# %%
df = csair[['收盘','变化率','变化','成交量']]
df.head()
# Out:
#      收盘       变化率        变化       成交量
# 0  6.01  0.665557 -0.661157  21898182
# 1  5.95  1.512605 -0.833333  28445196
# 2  5.88  1.190476 -1.010101  26998688
# 3  5.91  0.676819  0.681431  39321672
# 4  5.89  0.339559  0.000000  21759570

# %%
csair['变化率']=(csair['最高']-csair['收盘'])/csair['收盘']*100
csair['变化']=(csair['收盘']-csair['开盘'])/csair['开盘']*100
csair.head()
# Out:
#             时间    开盘    最高    最低    收盘       成交量       变化率        变化
# 0   2021/07/01  6.05  6.05  5.99  6.01  21898182  0.665557 -0.661157
# 1   2021/07/02  6.00  6.04  5.94  5.95  28445196  1.512605 -0.833333
# 2   2021/07/05  5.94  5.95  5.85  5.88  26998688  1.190476 -1.010101
# 3   2021/07/06  5.87  5.95  5.84  5.91  39321672  0.676819  0.681431
# 4   2021/07/07  5.89  5.91  5.85  5.89  21759570  0.339559  0.000000

# %%
csair.columns=['时间','开盘','最高','最低','收盘','成交量']
csair.head()
# Out:
#             时间    开盘    最高    最低    收盘       成交量
# 0   2021/07/01  6.05  6.05  5.99  6.01  21898182
# 1   2021/07/02  6.00  6.04  5.94  5.95  28445196
# 2   2021/07/05  5.94  5.95  5.85  5.88  26998688
# 3   2021/07/06  5.87  5.95  5.84  5.91  39321672
# 4   2021/07/07  5.89  5.91  5.85  5.89  21759570

# %%
csair.drop('VOL-TDX.VOLUME',inplace=True,axis=1)

# %%
csair = pd.read_excel('南方航空.xlsx'
                      )

# %%
csair.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   时间      420 non-null    object
#  1   开盘      420 non-null    float64
#  2   最高      420 non-null    float64
#  3   最低      420 non-null    float64
#  4   收盘      420 non-null    float64
#  5   成交量     420 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 19.8+ KB

# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import os
os.chdir(r'C:\Users\fzh00\Desktop\文件\excel')
