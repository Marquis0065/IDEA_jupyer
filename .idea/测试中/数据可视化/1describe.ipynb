# %%
plt.scatter(snd['AREA'],snd['price'])

# %%
snd.plot.scatter(x = 'AREA', y = 'price')
# Out:
# <AxesSubplot: xlabel='AREA', ylabel='price'>

# %%
snd.pivot_table(values='price', index='district', columns='school', aggfunc=np.mean)
# Out:
# school               0             1
# district
# 东城区       66276.887931  78514.900392
# 丰台区       42291.003505  48871.617021
# 朝阳区       51588.511689  57403.405360
# 海淀区       61385.803653  76911.258297
# 石景山区      40353.883878  33107.333333
# 西城区       76989.369511  92468.873623

# %%
sns.boxplot(x = 'district', y = 'price', data = snd)
# Out:
# <AxesSubplot: xlabel='district', ylabel='price'>

# %%
snd.price.groupby(snd.district).mean().sort_values(ascending= True).plot(kind = 'barh')
# Out:
# <AxesSubplot: ylabel='district'>

# %%
snd.price.groupby(snd.district).mean()
# Out:
# district
# 东城区     71883.595041
# 丰台区     42500.904309
# 朝阳区     52800.624651
# 海淀区     68757.602261
# 石景山区    40286.889574
# 西城区     85674.778545
# Name: price, dtype: float64

# %%
snd.price.groupby(snd.district).mean().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='district'>

# %%
from stack2dim import *

stack2dim(snd, i="district", j="school")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 from stack2dim import *
#       3 stack2dim(snd, i="district", j="school")
#
# ModuleNotFoundError: No module named 'stack2dim'

# %%
sub_sch
# Out:
# school           0         1  sum1
# district
# 东城区       0.270931  0.229069   0.5
# 丰台区       0.484052  0.015948   0.5
# 朝阳区       0.395775  0.104225   0.5
# 海淀区       0.262590  0.237410   0.5
# 石景山区      0.495378  0.004622   0.5
# 西城区       0.219455  0.280545   0.5

# %%
plt.bar(sub_sch.index,sub_sch[[0,1]],width=0.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 plt.bar(sub_sch.index,sub_sch[[0,1]],width=0.8)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2375, in bar(x, height, width, bottom, align, data, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.bar)
#    2372 def bar(
#    2373         x, height, width=0.8, bottom=None, *, align='center',
#    2374         data=None, **kwargs):
# -> 2375     return gca().bar(
#    2376         x, height, width=width, bottom=bottom, align=align,
#    2377         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_axes.py:2397, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2394     if yerr is not None:
#    2395         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2397 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2398     # Make args iterable too.
#    2399     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2401 # Now that units have been converted, set the tick locations.
#    2402 if orientation == 'vertical':
#
# File <__array_function__ internals>:180, in broadcast_arrays(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\cda_python\lib\site-packages\numpy\lib\stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File C:\ProgramData\Anaconda3\envs\cda_python\lib\site-packages\numpy\lib\stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (6,) and arg 1 with shape (2,).

# %%
sub_sch[[0,1]].plot(kind = 'bar',stacked= True)
# Out:
# <AxesSubplot: xlabel='district'>

# %%
sub_sch = sub_sch.div(sub_sch.sum(1),axis = 0)
sub_sch
# Out:
# school           0         1  sum1
# district
# 东城区       0.270931  0.229069   0.5
# 丰台区       0.484052  0.015948   0.5
# 朝阳区       0.395775  0.104225   0.5
# 海淀区       0.262590  0.237410   0.5
# 石景山区      0.495378  0.004622   0.5
# 西城区       0.219455  0.280545   0.5

# %%
sub_sch.sum(1)
# Out:
# district
# 东城区     5566
# 丰台区     5894
# 朝阳区     5728
# 海淀区     5838
# 石景山区    3894
# 西城区     5500
# dtype: int64

# %%
sub_sch = pd.crosstab(snd.district,snd.school)
sub_sch["sum1"]=sub_sch.sum(1)
sub_sch.head()
# Out:
# school       0     1  sum1
# district
# 东城区       1508  1275  2783
# 丰台区       2853    94  2947
# 朝阳区       2267   597  2864
# 海淀区       1533  1386  2919
# 石景山区      1929    18  1947

# %%
pd.crosstab(snd.district,snd.school).plot(kind = 'bar',stacked= True)
# Out:
# <AxesSubplot: xlabel='district'>

# %%
plt.bar(pd.crosstab(snd.dist,snd.subway)[0],
         pd.crosstab(snd.dist,snd.subway)[1])
# Out:
# <BarContainer object of 6 artists>

# %%
pd.crosstab(snd.dist,snd.subway)[0]
# Out:
# dist
# chaoyang       325
# dongcheng      142
# fengtai        719
# haidian        588
# shijingshan    718
# xicheng        299
# Name: 0, dtype: int64

# %%
pd.crosstab(snd.dist,snd.subway).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='dist'>

# %%
pd.pivot_table(snd,index=['district'],values=['school'],aggfunc=[''])
# Out:
#           count
#          school
# district
# 东城区        2783
# 丰台区        2947
# 朝阳区        2864
# 海淀区        2919
# 石景山区       1947
# 西城区        2750

# %%
sub_sch = pd.crosstab(snd.district,snd.school)
sub_sch
# Out:
# school       0     1
# district
# 东城区       1508  1275
# 丰台区       2853    94
# 朝阳区       2267   597
# 海淀区       1533  1386
# 石景山区      1929    18
# 西城区       1207  1543

# %%
plt.hist(snd.price,bins=40);

# %%
snd.price.hist(bins=40)
# Out:
# <AxesSubplot: >

# %%
snd.price.quantile([0.01,0.5,0.99])
# Out:
# 0.01     27104.45
# 0.50     57473.00
# 0.99    119996.85
# Name: price, dtype: float64

# %%
snd.price.agg(['mean','median','sum','std','skew'])
# Out:
# mean      6.115181e+04
# median    5.747300e+04
# sum       9.912709e+08
# std       2.229336e+04
# skew      6.794936e-01
# Name: price, dtype: float64

# %%
snd.price.std()
snd.price.skew()
# Out:
# 22293.35814732866
# 0.6794935869486859

# %%
snd.price.mean()
# Out:
# 61151.810919185686

# %%
snd.district.value_counts().plot(kind = 'bar');

# %%
#如遇中文显示问题可加入以下代码
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
district = {'fengtai':'丰台区','haidian':'海淀区','chaoyang':'朝阳区','dongcheng':'东城区','xicheng':'西城区','shijingshan':'石景山区'}
snd['district'] = snd.dist.map(district)
# snd_new = snd.drop('dist',axis = 1)
snd.head()
# Out:
#        dist  roomnum  halls    AREA   floor  subway  school  price  \
# 0  chaoyang        1      0   46.06  middle       1       0  48850
# 1  chaoyang        1      1   59.09  middle       1       0  46540
# 2   haidian        5      2  278.95    high       1       1  71662
# 3   haidian        3      2  207.00    high       1       1  57972
# 4   fengtai        2      1   53.32     low       1       1  71268
#
#        all_pr2 district
# 0   2250031.00      朝阳区
# 1   2750048.60      朝阳区
# 2  19990114.90      海淀区
# 3  12000204.00      海淀区
# 4   3800009.76      丰台区

# %%
snd["all_pr2"]=snd[["price","AREA"]].apply(lambda x:x[0]*x[1], axis = 1 )
snd.head()
# Out:
#        dist  roomnum  halls    AREA   floor  subway  school  price  \
# 0  chaoyang        1      0   46.06  middle       1       0  48850
# 1  chaoyang        1      1   59.09  middle       1       0  46540
# 2   haidian        5      2  278.95    high       1       1  71662
# 3   haidian        3      2  207.00    high       1       1  57972
# 4   fengtai        2      1   53.32     low       1       1  71268
#
#        all_pr2
# 0   2250031.00
# 1   2750048.60
# 2  19990114.90
# 3  12000204.00
# 4   3800009.76

# %%
snd.shape
# Out:
# (16210, 8)

# %%
snd.dist.value_counts()
# Out:
# fengtai        2947
# haidian        2919
# chaoyang       2864
# dongcheng      2783
# xicheng        2750
# shijingshan    1947
# Name: dist, dtype: int64

# %%
snd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16210 entries, 0 to 16209
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dist     16210 non-null  object
#  1   roomnum  16210 non-null  int64
#  2   halls    16210 non-null  int64
#  3   AREA     16210 non-null  float64
#  4   floor    16210 non-null  object
#  5   subway   16210 non-null  int64
#  6   school   16210 non-null  int64
#  7   price    16210 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 1013.2+ KB

# %%
snd.head(3)
# Out:
#        dist  roomnum  halls    AREA   floor  subway  school  price
# 0  chaoyang        1      0   46.06  middle       1       0  48850
# 1  chaoyang        1      1   59.09  middle       1       0  46540
# 2   haidian        5      2  278.95    high       1       1  71662

# %%
snd = pd.read_csv("C:\Data\Jupyter_file\统计建模\综合案例-个人贷款精准营销-上课前发给学员\参考代码_建模用代码\分类变量关系的展示\demo\sndHsPr.csv")

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
